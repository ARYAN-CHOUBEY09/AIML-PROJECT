# %% [markdown]
# ### TEXT LOADER AND TEXT SPLITING

# %%
pip install langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain langchain-community
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("Tata_Motors.txt")
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'Tata_Motors.txt'}, page_content='Tata Motors\n\n\n\nTata Motors LimitedHeadquarters in MumbaiFormerlyTata Engineering and Locomotive Company Ltd. (TELCO)Company typePublicTraded asBSE:Â\xa0500570NSE:Â\xa0TATAMOTORSBSE SENSEX constituentNSE NIFTY 50 constituentISININ9155A01020IndustryAutomotiveFounded1945; 79Â\xa0years agoFounderJ. R. D. TataHeadquartersMumbai, Maharashtra, India[1]Area servedWorldwideKey peopleNatarajan Chandrasekaran  (Chairman)P. B. Balaji (CFO)[2]ProductsAutomobilesLuxury vehiclesCommercial vehiclesAutomotive partsPickup trucksSUVsProduction output1.1 million (2021)ServicesAutomotive financeVehicle leasingVehicle serviceRevenue â‚¹443,877 crore (US$53Â\xa0billion) (2024)[3]Operating income â‚¹28,232 crore (US$3.4Â\xa0billion) (2024)[3]Net income â‚¹31,806 crore (US$3.8Â\xa0billion) (2024)[3]Total assets â‚¹370,663 crore (US$44Â\xa0billion) (2024)[4]Total equity â‚¹93,093 crore (US$11Â\xa0billion) (2024)[4]Number of employees91,811 (2
# ...

# %%
type(data)
# Out:
# list

# %%
len(data
)
# Out:
# 1

# %%
data[0]
# Out:
# Document(metadata={'source': 'Tata_Motors.txt'}, page_content='Tata Motors\n\n\n\nTata Motors LimitedHeadquarters in MumbaiFormerlyTata Engineering and Locomotive Company Ltd. (TELCO)Company typePublicTraded asBSE:Â\xa0500570NSE:Â\xa0TATAMOTORSBSE SENSEX constituentNSE NIFTY 50 constituentISININ9155A01020IndustryAutomotiveFounded1945; 79Â\xa0years agoFounderJ. R. D. TataHeadquartersMumbai, Maharashtra, India[1]Area servedWorldwideKey peopleNatarajan Chandrasekaran  (Chairman)P. B. Balaji (CFO)[2]ProductsAutomobilesLuxury vehiclesCommercial vehiclesAutomotive partsPickup trucksSUVsProduction output1.1 million (2021)ServicesAutomotive financeVehicle leasingVehicle serviceRevenue â‚¹443,877 crore (US$53Â\xa0billion) (2024)[3]Operating income â‚¹28,232 crore (US$3.4Â\xa0billion) (2024)[3]Net income â‚¹31,806 crore (US$3.8Â\xa0billion) (2024)[3]Total assets â‚¹370,663 crore (US$44Â\xa0billion) (2024)[4]Total equity â‚¹93,093 crore (US$11Â\xa0billion) (2024)[4]Number of employees91,811 (20
# ...

# %%
type(data[0])
# Out:
# langchain_core.documents.base.Document

# %%
data[0].metadata
# Out:
# {'source': 'Tata_Motors.txt'}

# %%
data[0].page_content
# Out:
# 'Tata Motors\n\n\n\nTata Motors LimitedHeadquarters in MumbaiFormerlyTata Engineering and Locomotive Company Ltd. (TELCO)Company typePublicTraded asBSE:Â\xa0500570NSE:Â\xa0TATAMOTORSBSE SENSEX constituentNSE NIFTY 50 constituentISININ9155A01020IndustryAutomotiveFounded1945; 79Â\xa0years agoFounderJ. R. D. TataHeadquartersMumbai, Maharashtra, India[1]Area servedWorldwideKey peopleNatarajan Chandrasekaran  (Chairman)P. B. Balaji (CFO)[2]ProductsAutomobilesLuxury vehiclesCommercial vehiclesAutomotive partsPickup trucksSUVsProduction output1.1 million (2021)ServicesAutomotive financeVehicle leasingVehicle serviceRevenue â‚¹443,877 crore (US$53Â\xa0billion) (2024)[3]Operating income â‚¹28,232 crore (US$3.4Â\xa0billion) (2024)[3]Net income â‚¹31,806 crore (US$3.8Â\xa0billion) (2024)[3]Total assets â‚¹370,663 crore (US$44Â\xa0billion) (2024)[4]Total equity â‚¹93,093 crore (US$11Â\xa0billion) (2024)[4]Number of employees91,811 (2024)[5]ParentTata GroupSubsidiaries\nTata Motors Cars\nJaguar L
# ...

# %% [markdown]
# ### LOADING CSV FILE ###

# %%
pip install langchain langchain-community
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader("movies.csv")

# %%
data=loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'movies.csv', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
# ...

# %%
len(data)
# Out:
# 9

# %%
data[0]
# Out:
# Document(metadata={'source': 'movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR')

# %%
data[0].metadata
# Out:
# {'source': 'movies.csv', 'row': 0}

# %%
loader = CSVLoader("movies.csv",source_column='title')
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'K.G.F: Chapter 2', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: The Dark World', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
# ...

# %%
data[0].metadata
# Out:
# {'source': 'K.G.F: Chapter 2', 'row': 0}

# %% [markdown]
# ### LOADING DATA FROM URL

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
pip install unstructured
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
loader = UnstructuredURLLoader(
    urls = [
        "https://www.moneycontrol.com/news/business/stocks/accumulate-tata-motors-target-of-rs-1075-prabhudas-lilladher-12538061.html",
        "https://www.moneycontrol.com/news/business/stocks/buy-tata-motors-target-of-rs-1188-sharekhan-12411611.html",
        "https://www.moneycontrol.com/news/business/stocks/reduce-tata-motors-target-of-rs-901-icici-securities-12411521.html"
        ]
)

# %%
data = loader.load()

# %%
len(data)
# Out:
# 3

# %%
data[0].page_content
# Out:
# "English\n\nHindi\n\nGujarati\n\nSpecials\n\nHello, Login\n\nHello, Login\n\nLog-inor Sign-Up\n\nMy Account\n\nMy Profile\n\nMy Portfolio\n\nMy Watchlist\n\nMy Alerts\n\nMy Messages\n\nPrice Alerts\n\
Tata Motors is listed on the BSE and NSE, and is part of the Sensex and Nifty 50.
The company was ranked 265th on the Fortune Global 500 list (2019).
On 17 January 2017, Natarajan Chandrasekaran was appointed chairman of Tata Group.
Tata Motors increased its UV market share to over 8% in FY2019.

History:
Tata Motors was founded in 1945 as a locomotive manufacturer.
Tata entered the commercial vehicle sector in 1954 after a JV with Daimler-Benz.
In 1991, Tata launched its first passenger vehicle, Tata Sierra.
Later models included Tata Estate (1992), Tata Sumo (1994), and Tata Safari (1998).
In 1998, Tata launched the Indica – India's first fully indigenous car.

In the 2000s, Tata Motors expanded globally:
- Acquired Daewoo's Korean truck unit
- JV with Marcopolo for buses
- Acquired Jaguar Land Rover
- Acquired Hispano Carrocera
- Bought 80% of Italian design firm Trilix

On 12 Oct 2021, TPG invested $1 billion into Tata Motors’ EV division.
"""

# %%
cleaned = text.replace('\u00a0', ' ')
cleaned
# Out:
# "\nTata Motors Limited Headquarters in Mumbai. Formerly Tata Engineering and Locomotive Company Ltd. (TELCO)\nCompany type: Public\nTraded as: BSE: 500570, NSE: TATAMOTORS\nBSE SENSEX constituent, NSE NIFTY 50 constituent\nISIN: IN9155A01020\nIndustry: Automotive\nFounded: 1945 (79 years ago)\nFounder: J. R. D. Tata\nHeadquarters: Mumbai, Maharashtra, India\nArea served: Worldwide\nKey people: Natarajan Chandrasekaran (Chairman), P. B. Balaji (CFO)\nProducts: Automobiles, Luxury vehicles, Commercial vehicles, Automotive parts, Pickup trucks, SUVs\nProduction output: 1.1 million (2021)\nServices: Automotive finance, Vehicle leasing, Vehicle service\nRevenue: ₹443,877 crore (US$53 billion) (2024)\nOperating income: ₹28,232 crore (US$3.4 billion) (2024)\nNet income: ₹31,806 crore (US$3.8 billion) (2024)\nTotal assets: ₹370,663 crore (US$44 billion) (2024)\nTotal equity: ₹93,093 crore (US$11 billion) (2024)\nNumber of employees: 91,811 (2024)\nParent: Tata Group\n\nSubsidiaries:\n- Tata 
# ...

# %%
text[0:100]
# Out:
# '\nTata Motors Limited Headquarters in Mumbai. Formerly Tata Engineering and Locomotive Company Ltd. ('

# %% [markdown]
# ### Character text spliter

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\DELL\anaconda3\python.exe

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.7

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=200,
    chunk_overlap=5
)

# %%
chunk = splitter.split_text(text)

# %%
len(chunk)
# Out:
# 17

# %%
for chunk in chunk:
    print(len(chunk))
# Out:
# 166
# 181
# 189
# 147
# 157
# 188
# 96
# 169
# 76
# 161
# 171
# 150
# 134
# 145
# 200
# 168
# 70

# %% [markdown]
# ## recursive text splitter

# %%
 from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", " "],
    chunk_size=200,
    chunk_overlap=0,
    length_function=len
)

# %%
chunk = splitter.split_text(text)

# %%
for chunk in chunk:
    print(len(chunk))
# Out:
# 166
# 181
# 189
# 147
# 157
# 104
# 181
# 169
# 76
# 161
# 171
# 150
# 63
# 151
# 148
# 71
# 170
# 42
# 70
